# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs =  np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    for coordinate in coordinates:
        city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities lis
        if city not in cities:
            cities.append(city)


# Print the city count to confirm sufficient count
len(cities)
# Out:
# 746

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=12e82e638640666b8bb5af42e138c6f3

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity']
        clouds = city_weather['clouds']['all']
        wind = city_weather['wind']['speed']
        country = city_weather['sys']['country']      
        weather_description = city_weather['weather'][0]['description']
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),
                          'Lat': lat, 
                          'Lng': lng, 
                          'Max Temp': max_temp, 
                          'Humidity': humidity, 
                          'Cloudiness': clouds, 
                          'Wind Speed': wind, 
                          'Country': country, 
                          'Current Description': weather_description
                          })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | nome
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | sola
# Processing Record 8 of Set 1 | nishihara
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | barranca
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | byron bay
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | port hardy
# Processing Record 18 of Set 1 | san rafael
# Processing Record 19 of Set 1 | samana
# Processing Record 20 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | prien
# Processing Record 23 of Set 1 | miedzychod
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | san jose
# Processing Record 27 of Set 1 | bathsheba
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | haines junction
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | atar
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 1 | bom jesus
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | devils lake
# Processing Record 44 of Set 1 | codrington
# Processing Record 45 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | grindavik
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | barra do garcas
# Processing Record 50 of Set 1 | karatu
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | hobyo
# Processing Record 4 of Set 2 | puerto madryn
# Processing Record 5 of Set 2 | rio gallegos
# Processing Record 6 of Set 2 | zatoka
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | botwood
# Processing Record 10 of Set 2 | xai-xai
# Processing Record 11 of Set 2 | kasempa
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | ayan
# Processing Record 16 of Set 2 | ialibu
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | troitsko-pechorsk
# Processing Record 19 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 2 | salalah
# Processing Record 21 of Set 2 | juba
# Processing Record 22 of Set 2 | san quintin
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | amuntai
# Processing Record 25 of Set 2 | mounana
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | kaeo
# Processing Record 30 of Set 2 | gazojak
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | klaksvik
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | sisimiut
# Processing Record 37 of Set 2 | burriana
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | marienburg
# Processing Record 40 of Set 2 | tyulyachi
# Processing Record 41 of Set 2 | inirida
# Processing Record 42 of Set 2 | erwitte
# Processing Record 43 of Set 2 | sinnamary
# Processing Record 44 of Set 2 | erenhot
# Processing Record 45 of Set 2 | paamiut
# Processing Record 46 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 2 | takaka
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | rikitea
# Processing Record 1 of Set 3 | cabadiangan
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | tautira
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | deputatskiy
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | igarka
# Processing Record 9 of Set 3 | luwingu
# Processing Record 10 of Set 3 | santa marta
# Processing Record 11 of Set 3 | stuttgart
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | jan kempdorp
# Processing Record 15 of Set 3 | harper
# Processing Record 16 of Set 3 | saint-pierre
# Processing Record 17 of Set 3 | taunggyi
# Processing Record 18 of Set 3 | honiara
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | abu samrah
# Processing Record 23 of Set 3 | tignere
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | selma
# Processing Record 27 of Set 3 | kapoeta
# Processing Record 28 of Set 3 | hammerfest
# Processing Record 29 of Set 3 | marevo
# Processing Record 30 of Set 3 | acaponeta
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | el alto
# Processing Record 33 of Set 3 | yumbo
# Processing Record 34 of Set 3 | samarai
# Processing Record 35 of Set 3 | kavieng
# Processing Record 36 of Set 3 | bacolod
# Processing Record 37 of Set 3 | grand gaube
# Processing Record 38 of Set 3 | constitucion
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 3 | la paz
# Processing Record 43 of Set 3 | hualmay
# Processing Record 44 of Set 3 | ulcinj
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | zheleznogorsk
# Processing Record 47 of Set 3 | bundaberg
# Processing Record 48 of Set 3 | kudahuvadhoo
# Processing Record 49 of Set 3 | qui nhon
# Processing Record 50 of Set 3 | acarau
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | quatre cocos
# Processing Record 3 of Set 4 | cupira
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | acapulco
# Processing Record 6 of Set 4 | morant bay
# Processing Record 7 of Set 4 | half moon bay
# Processing Record 8 of Set 4 | jalu
# Processing Record 9 of Set 4 | bulawayo
# Processing Record 10 of Set 4 | fortuna
# Processing Record 11 of Set 4 | inverell
# Processing Record 12 of Set 4 | les cayes
# Processing Record 13 of Set 4 | soyo
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | tamiahua
# Processing Record 16 of Set 4 | qasigiannguit
# Processing Record 17 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 4 | pochutla
# Processing Record 19 of Set 4 | los llanos de aridane
# Processing Record 20 of Set 4 | asyut
# Processing Record 21 of Set 4 | maneadero
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 4 | dingle
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | taoudenni
# Processing Record 27 of Set 4 | mnogovershinnyy
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | hovd
# Processing Record 30 of Set 4 | alta floresta
# Processing Record 31 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 4 | florence
# Processing Record 33 of Set 4 | darnah
# Processing Record 34 of Set 4 | bojaya
# City not found. Skipping...
# Processing Record 35 of Set 4 | cibitoke
# Processing Record 36 of Set 4 | concepcion
# Processing Record 37 of Set 4 | zhigansk
# Processing Record 38 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | prince rupert
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | inuvik
# Processing Record 43 of Set 4 | atuona
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | broome
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | srednekolymsk
# Processing Record 50 of Set 4 | sibolga
# Processing Record 1 of Set 5 | hobart
# Processing Record 2 of Set 5 | kouango
# Processing Record 3 of Set 5 | high level
# Processing Record 4 of Set 5 | batagay
# Processing Record 5 of Set 5 | yulara
# Processing Record 6 of Set 5 | dikson
# Processing Record 7 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | rawatbhata
# Processing Record 10 of Set 5 | nongstoin
# Processing Record 11 of Set 5 | zharkent
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | porto novo
# Processing Record 14 of Set 5 | den helder
# Processing Record 15 of Set 5 | shirokiy
# Processing Record 16 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 5 | rocha
# Processing Record 18 of Set 5 | new norfolk
# Processing Record 19 of Set 5 | morondava
# Processing Record 20 of Set 5 | liverpool
# Processing Record 21 of Set 5 | dothan
# Processing Record 22 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 5 | kloulklubed
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | roman
# Processing Record 26 of Set 5 | bauchi
# Processing Record 27 of Set 5 | belmonte
# Processing Record 28 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 5 | ginda
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | manchester
# Processing Record 35 of Set 5 | san vicente de canete
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | derzhavinsk
# Processing Record 38 of Set 5 | xingyi
# Processing Record 39 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | fulton
# Processing Record 43 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 5 | edwardsville
# Processing Record 45 of Set 5 | changji
# Processing Record 46 of Set 5 | saldanha
# Processing Record 47 of Set 5 | chajul
# Processing Record 48 of Set 5 | havoysund
# Processing Record 49 of Set 5 | mantua
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | tommot
# Processing Record 2 of Set 6 | valdivia
# Processing Record 3 of Set 6 | matara
# Processing Record 4 of Set 6 | lorengau
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | sao joao da barra
# Processing Record 7 of Set 6 | castro
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | joshimath
# Processing Record 10 of Set 6 | ribeira grande
# Processing Record 11 of Set 6 | salinopolis
# Processing Record 12 of Set 6 | kollam
# Processing Record 13 of Set 6 | turukhansk
# Processing Record 14 of Set 6 | novoagansk
# Processing Record 15 of Set 6 | mehamn
# Processing Record 16 of Set 6 | puksoozero
# Processing Record 17 of Set 6 | vostok
# Processing Record 18 of Set 6 | upington
# Processing Record 19 of Set 6 | esperance
# Processing Record 20 of Set 6 | meulaboh
# Processing Record 21 of Set 6 | chuy
# Processing Record 22 of Set 6 | mount gambier
# Processing Record 23 of Set 6 | saurimo
# Processing Record 24 of Set 6 | ocampo
# Processing Record 25 of Set 6 | burnie
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | husavik
# Processing Record 28 of Set 6 | ulladulla
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | flinders
# Processing Record 32 of Set 6 | mitsamiouli
# Processing Record 33 of Set 6 | hami
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | saint-francois
# Processing Record 36 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 6 | taksimo
# Processing Record 38 of Set 6 | upernavik
# Processing Record 39 of Set 6 | kieta
# Processing Record 40 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 6 | cedar city
# Processing Record 42 of Set 6 | dhankuta
# Processing Record 43 of Set 6 | taga
# Processing Record 44 of Set 6 | naryan-mar
# Processing Record 45 of Set 6 | reconquista
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | aklavik
# Processing Record 48 of Set 6 | luau
# Processing Record 49 of Set 6 | severodvinsk
# Processing Record 50 of Set 6 | mackay
# Processing Record 1 of Set 7 | det udom
# Processing Record 2 of Set 7 | namibe
# Processing Record 3 of Set 7 | cajati
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | tuatapere
# Processing Record 6 of Set 7 | nanakuli
# Processing Record 7 of Set 7 | goose creek
# Processing Record 8 of Set 7 | arkhipo-osipovka
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | matamoros
# Processing Record 11 of Set 7 | coffs harbour
# Processing Record 12 of Set 7 | opuwo
# Processing Record 13 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 7 | buraydah
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | tigil
# Processing Record 17 of Set 7 | bilma
# Processing Record 18 of Set 7 | sept-iles
# Processing Record 19 of Set 7 | beaverlodge
# Processing Record 20 of Set 7 | bredasdorp
# Processing Record 21 of Set 7 | along
# Processing Record 22 of Set 7 | katsuura
# Processing Record 23 of Set 7 | semnan
# Processing Record 24 of Set 7 | kulunda
# Processing Record 25 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 26 of Set 7 | burns lake
# Processing Record 27 of Set 7 | vigrestad
# Processing Record 28 of Set 7 | altagracia de orituco
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | muzhi
# Processing Record 31 of Set 7 | mola di bari
# Processing Record 32 of Set 7 | abha
# Processing Record 33 of Set 7 | mawlaik
# Processing Record 34 of Set 7 | sorong
# Processing Record 35 of Set 7 | honningsvag
# Processing Record 36 of Set 7 | jatai
# Processing Record 37 of Set 7 | glenwood springs
# Processing Record 38 of Set 7 | kushmurun
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 7 | aloleng
# Processing Record 43 of Set 7 | fort nelson
# Processing Record 44 of Set 7 | novo aripuana
# Processing Record 45 of Set 7 | chapais
# Processing Record 46 of Set 7 | kangayam
# Processing Record 47 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 7 | chifeng
# Processing Record 49 of Set 7 | bellinzona
# Processing Record 50 of Set 7 | ulagan
# Processing Record 1 of Set 8 | baiyin
# Processing Record 2 of Set 8 | lagoa
# Processing Record 3 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 8 | rabo de peixe
# Processing Record 5 of Set 8 | san matias
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | yumen
# Processing Record 8 of Set 8 | golden
# Processing Record 9 of Set 8 | chakulia
# Processing Record 10 of Set 8 | saint-jean-de-la-ruelle
# Processing Record 11 of Set 8 | altea
# Processing Record 12 of Set 8 | kibara
# Processing Record 13 of Set 8 | monrovia
# Processing Record 14 of Set 8 | port moresby
# Processing Record 15 of Set 8 | simpsonville
# Processing Record 16 of Set 8 | sarkand
# Processing Record 17 of Set 8 | oskarshamn
# Processing Record 18 of Set 8 | pinawa
# Processing Record 19 of Set 8 | cabo san lucas
# Processing Record 20 of Set 8 | ponta delgada
# Processing Record 21 of Set 8 | maarianhamina
# Processing Record 22 of Set 8 | toba
# Processing Record 23 of Set 8 | poum
# Processing Record 24 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 25 of Set 8 | yangliuqing
# Processing Record 26 of Set 8 | preobrazheniye
# Processing Record 27 of Set 8 | ambilobe
# Processing Record 28 of Set 8 | kholodnyy
# Processing Record 29 of Set 8 | longhua
# Processing Record 30 of Set 8 | magadan
# Processing Record 31 of Set 8 | videira
# Processing Record 32 of Set 8 | koboldo
# City not found. Skipping...
# Processing Record 33 of Set 8 | daugavpils
# Processing Record 34 of Set 8 | pishin
# Processing Record 35 of Set 8 | ca mau
# Processing Record 36 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 8 | karaton
# Processing Record 38 of Set 8 | svetlogorsk
# Processing Record 39 of Set 8 | bafia
# Processing Record 40 of Set 8 | ruteng
# Processing Record 41 of Set 8 | imeni poliny osipenko
# Processing Record 42 of Set 8 | dombarovskiy
# Processing Record 43 of Set 8 | nowa deba
# Processing Record 44 of Set 8 | vestmannaeyjar
# Processing Record 45 of Set 8 | guerrero negro
# Processing Record 46 of Set 8 | amontada
# Processing Record 47 of Set 8 | tromso
# Processing Record 48 of Set 8 | port blair
# Processing Record 49 of Set 8 | medina
# Processing Record 50 of Set 8 | sabang
# Processing Record 1 of Set 9 | luganville
# Processing Record 2 of Set 9 | kryvyy rih
# Processing Record 3 of Set 9 | norrkoping
# Processing Record 4 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 5 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 6 of Set 9 | sillod
# Processing Record 7 of Set 9 | adrar
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | faya
# Processing Record 10 of Set 9 | yar-sale
# Processing Record 11 of Set 9 | harbour breton
# Processing Record 12 of Set 9 | bengkulu
# Processing Record 13 of Set 9 | kirkenaer
# Processing Record 14 of Set 9 | garowe
# Processing Record 15 of Set 9 | acajutla
# Processing Record 16 of Set 9 | new ulm
# Processing Record 17 of Set 9 | ingham
# Processing Record 18 of Set 9 | arlit
# Processing Record 19 of Set 9 | hay river
# Processing Record 20 of Set 9 | surt
# Processing Record 21 of Set 9 | kokopo
# Processing Record 22 of Set 9 | karratha
# Processing Record 23 of Set 9 | silver city
# Processing Record 24 of Set 9 | mogadishu
# Processing Record 25 of Set 9 | muros
# Processing Record 26 of Set 9 | lumeje
# Processing Record 27 of Set 9 | ranong
# Processing Record 28 of Set 9 | nemuro
# Processing Record 29 of Set 9 | marataizes
# Processing Record 30 of Set 9 | mecca
# Processing Record 31 of Set 9 | kropotkin
# Processing Record 32 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 33 of Set 9 | vangaindrano
# Processing Record 34 of Set 9 | menongue
# Processing Record 35 of Set 9 | sistranda
# Processing Record 36 of Set 9 | omsukchan
# Processing Record 37 of Set 9 | mabaruma
# Processing Record 38 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 9 | aniva
# Processing Record 40 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 9 | naze
# Processing Record 42 of Set 9 | amurzet
# Processing Record 43 of Set 9 | hearst
# Processing Record 44 of Set 9 | ambanja
# Processing Record 45 of Set 9 | galesong
# Processing Record 46 of Set 9 | malakal
# Processing Record 47 of Set 9 | beloha
# Processing Record 48 of Set 9 | gazipur
# Processing Record 49 of Set 9 | solnechnyy
# Processing Record 50 of Set 9 | alyangula
# Processing Record 1 of Set 10 | san vicente
# Processing Record 2 of Set 10 | dabeiba
# Processing Record 3 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 4 of Set 10 | mananjary
# Processing Record 5 of Set 10 | lamu
# Processing Record 6 of Set 10 | los zacatones
# Processing Record 7 of Set 10 | koslan
# Processing Record 8 of Set 10 | catia la mar
# Processing Record 9 of Set 10 | chumikan
# Processing Record 10 of Set 10 | havre-saint-pierre
# Processing Record 11 of Set 10 | lafiagi
# Processing Record 12 of Set 10 | shitanjing
# Processing Record 13 of Set 10 | port augusta
# Processing Record 14 of Set 10 | pelagiada
# Processing Record 15 of Set 10 | puerto carreno
# Processing Record 16 of Set 10 | schneeberg
# Processing Record 17 of Set 10 | asau
# Processing Record 18 of Set 10 | baghdad
# Processing Record 19 of Set 10 | kenscoff
# Processing Record 20 of Set 10 | santa maria
# Processing Record 21 of Set 10 | akyab
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | el dorado
# Processing Record 24 of Set 10 | rio verde de mato grosso
# Processing Record 25 of Set 10 | banepa
# Processing Record 26 of Set 10 | ushumun
# Processing Record 27 of Set 10 | krasnyy chikoy
# Processing Record 28 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 29 of Set 10 | halifax
# Processing Record 30 of Set 10 | nicholasville
# Processing Record 31 of Set 10 | gao
# Processing Record 32 of Set 10 | tazovskiy
# Processing Record 33 of Set 10 | camacupa
# Processing Record 34 of Set 10 | lingyuan
# Processing Record 35 of Set 10 | cascais
# Processing Record 36 of Set 10 | sheridan
# Processing Record 37 of Set 10 | wundanyi
# Processing Record 38 of Set 10 | normandin
# Processing Record 39 of Set 10 | kalmunai
# Processing Record 40 of Set 10 | vyazemskiy
# Processing Record 41 of Set 10 | bullhead city
# Processing Record 42 of Set 10 | dunedin
# Processing Record 43 of Set 10 | raudeberg
# Processing Record 44 of Set 10 | kathu
# Processing Record 45 of Set 10 | bandrele
# Processing Record 46 of Set 10 | pangkalanbuun
# Processing Record 47 of Set 10 | marystown
# Processing Record 48 of Set 10 | esso
# Processing Record 49 of Set 10 | waipawa
# Processing Record 50 of Set 10 | krasnoselkup
# Processing Record 1 of Set 11 | sechura
# Processing Record 2 of Set 11 | olafsvik
# Processing Record 3 of Set 11 | kananga
# Processing Record 4 of Set 11 | russell
# Processing Record 5 of Set 11 | borama
# City not found. Skipping...
# Processing Record 6 of Set 11 | gorom-gorom
# Processing Record 7 of Set 11 | college
# Processing Record 8 of Set 11 | rudnogorsk
# Processing Record 9 of Set 11 | smithers
# Processing Record 10 of Set 11 | lardos
# Processing Record 11 of Set 11 | nauta
# Processing Record 12 of Set 11 | mana
# Processing Record 13 of Set 11 | tra vinh
# Processing Record 14 of Set 11 | faanui
# Processing Record 15 of Set 11 | isla vista
# Processing Record 16 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 17 of Set 11 | dukat
# Processing Record 18 of Set 11 | port-gentil
# Processing Record 19 of Set 11 | winfield
# Processing Record 20 of Set 11 | almaznyy
# Processing Record 21 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 22 of Set 11 | kabarnet
# Processing Record 23 of Set 11 | avera
# Processing Record 24 of Set 11 | tiebissou
# Processing Record 25 of Set 11 | antigonish
# Processing Record 26 of Set 11 | port shepstone
# Processing Record 27 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 11 | saint-joseph
# Processing Record 29 of Set 11 | shestakovo
# Processing Record 30 of Set 11 | puerto narino
# Processing Record 31 of Set 11 | saint-augustin
# Processing Record 32 of Set 11 | stolin
# Processing Record 33 of Set 11 | nabire
# Processing Record 34 of Set 11 | vanavara
# Processing Record 35 of Set 11 | makat
# Processing Record 36 of Set 11 | parrita
# Processing Record 37 of Set 11 | mushie
# Processing Record 38 of Set 11 | bambanglipuro
# Processing Record 39 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 11 | oussouye
# Processing Record 41 of Set 11 | xitla
# City not found. Skipping...
# Processing Record 42 of Set 11 | nara
# Processing Record 43 of Set 11 | save
# Processing Record 44 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 11 | sobolevo
# Processing Record 46 of Set 11 | teguldet
# Processing Record 47 of Set 11 | merauke
# Processing Record 48 of Set 11 | rincon
# Processing Record 49 of Set 11 | bemidji
# Processing Record 50 of Set 11 | manavalakurichi
# Processing Record 1 of Set 12 | warwick
# Processing Record 2 of Set 12 | gorontalo
# Processing Record 3 of Set 12 | lakeside
# Processing Record 4 of Set 12 | fare
# Processing Record 5 of Set 12 | nabinagar
# Processing Record 6 of Set 12 | alofi
# Processing Record 7 of Set 12 | talcahuano
# Processing Record 8 of Set 12 | darab
# Processing Record 9 of Set 12 | dubbo
# Processing Record 10 of Set 12 | makakilo city
# Processing Record 11 of Set 12 | nagato
# Processing Record 12 of Set 12 | amberieu-en-bugey
# Processing Record 13 of Set 12 | sao filipe
# Processing Record 14 of Set 12 | mareeba
# Processing Record 15 of Set 12 | arvika
# Processing Record 16 of Set 12 | ketchikan
# Processing Record 17 of Set 12 | san juan
# Processing Record 18 of Set 12 | huarmey
# Processing Record 19 of Set 12 | cortes
# Processing Record 20 of Set 12 | tiarei
# Processing Record 21 of Set 12 | tezpur
# Processing Record 22 of Set 12 | green valley
# Processing Record 23 of Set 12 | davila
# Processing Record 24 of Set 12 | tari
# Processing Record 25 of Set 12 | freeport
# Processing Record 26 of Set 12 | namatanai
# Processing Record 27 of Set 12 | tual
# Processing Record 28 of Set 12 | killam
# Processing Record 29 of Set 12 | sigulda
# Processing Record 30 of Set 12 | cristinapolis
# Processing Record 31 of Set 12 | yamada
# Processing Record 32 of Set 12 | jieshi
# Processing Record 33 of Set 12 | poronaysk
# Processing Record 34 of Set 12 | zyryanovsk
# Processing Record 35 of Set 12 | leh
# Processing Record 36 of Set 12 | holeby
# Processing Record 37 of Set 12 | yuli
# Processing Record 38 of Set 12 | nantucket
# Processing Record 39 of Set 12 | meiktila
# Processing Record 40 of Set 12 | coruripe
# Processing Record 41 of Set 12 | nisia floresta
# Processing Record 42 of Set 12 | klyuchi
# Processing Record 43 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 44 of Set 12 | san-pedro
# Processing Record 45 of Set 12 | vigeland
# Processing Record 46 of Set 12 | camacha
# Processing Record 47 of Set 12 | pato branco
# Processing Record 48 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 49 of Set 12 | qaqortoq
# Processing Record 50 of Set 12 | cortez
# Processing Record 1 of Set 13 | buin
# Processing Record 2 of Set 13 | puerto escondido
# Processing Record 3 of Set 13 | polson
# Processing Record 4 of Set 13 | pacifica
# Processing Record 5 of Set 13 | beaver dam
# Processing Record 6 of Set 13 | almeria
# Processing Record 7 of Set 13 | richards bay
# Processing Record 8 of Set 13 | rockland
# Processing Record 9 of Set 13 | anadyr
# Processing Record 10 of Set 13 | cabedelo
# Processing Record 11 of Set 13 | andenes
# Processing Record 12 of Set 13 | wattegama
# Processing Record 13 of Set 13 | pryazha
# Processing Record 14 of Set 13 | inhambane
# Processing Record 15 of Set 13 | burica
# City not found. Skipping...
# Processing Record 16 of Set 13 | nikolayevsk-na-amure
# Processing Record 17 of Set 13 | ambulu
# Processing Record 18 of Set 13 | torzhok
# Processing Record 19 of Set 13 | penzance
# Processing Record 20 of Set 13 | rehoboth
# Processing Record 21 of Set 13 | salisbury
# Processing Record 22 of Set 13 | verkhnevilyuysk
# Processing Record 23 of Set 13 | chicama
# Processing Record 24 of Set 13 | mercedes
# Processing Record 25 of Set 13 | puerto ayacucho
# Processing Record 26 of Set 13 | marigot
# Processing Record 27 of Set 13 | san pedro buenavista
# Processing Record 28 of Set 13 | valkeakoski
# Processing Record 29 of Set 13 | kurchum
# Processing Record 30 of Set 13 | axim
# Processing Record 31 of Set 13 | balakhninskiy
# Processing Record 32 of Set 13 | biltine
# Processing Record 33 of Set 13 | majene
# Processing Record 34 of Set 13 | borujan
# City not found. Skipping...
# Processing Record 35 of Set 13 | tsaratanana
# Processing Record 36 of Set 13 | celestun
# Processing Record 37 of Set 13 | yuanping
# Processing Record 38 of Set 13 | shenjiamen
# Processing Record 39 of Set 13 | kupang
# Processing Record 40 of Set 13 | black river
# Processing Record 41 of Set 13 | kungurtug
# Processing Record 42 of Set 13 | manzhouli
# Processing Record 43 of Set 13 | vila
# Processing Record 44 of Set 13 | nuristan
# Processing Record 45 of Set 13 | xuddur
# Processing Record 46 of Set 13 | ariquemes
# Processing Record 47 of Set 13 | thinadhoo
# Processing Record 48 of Set 13 | moshenskoye
# Processing Record 49 of Set 13 | kota
# Processing Record 50 of Set 13 | nouadhibou
# Processing Record 1 of Set 14 | tilichiki
# Processing Record 2 of Set 14 | havelock
# Processing Record 3 of Set 14 | tolga
# Processing Record 4 of Set 14 | elat
# Processing Record 5 of Set 14 | great bend
# Processing Record 6 of Set 14 | srivardhan
# Processing Record 7 of Set 14 | khandyga
# Processing Record 8 of Set 14 | pasan
# Processing Record 9 of Set 14 | palmer
# Processing Record 10 of Set 14 | north bend
# Processing Record 11 of Set 14 | nokaneng
# Processing Record 12 of Set 14 | saint-ambroise
# Processing Record 13 of Set 14 | barabash
# Processing Record 14 of Set 14 | portland
# Processing Record 15 of Set 14 | saint-denis
# Processing Record 16 of Set 14 | jawhar
# Processing Record 17 of Set 14 | aldan
# Processing Record 18 of Set 14 | babu
# Processing Record 19 of Set 14 | annau
# Processing Record 20 of Set 14 | mixtepec
# City not found. Skipping...
# Processing Record 21 of Set 14 | itarema
# Processing Record 22 of Set 14 | seoul
# Processing Record 23 of Set 14 | kiunga
# Processing Record 24 of Set 14 | gat
# Processing Record 25 of Set 14 | calabozo
# Processing Record 26 of Set 14 | caraballeda
# Processing Record 27 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | sakakah
# Processing Record 29 of Set 14 | neuquen
# Processing Record 30 of Set 14 | mount isa
# Processing Record 31 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 14 | salym
# Processing Record 33 of Set 14 | darlowo
# Processing Record 34 of Set 14 | agadez
# Processing Record 35 of Set 14 | ahipara
# Processing Record 36 of Set 14 | chernyshevsk
# Processing Record 37 of Set 14 | sumbal
# Processing Record 38 of Set 14 | hella
# Processing Record 39 of Set 14 | cooma
# Processing Record 40 of Set 14 | moche
# Processing Record 41 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 14 | kaoma
# Processing Record 43 of Set 14 | ballina
# Processing Record 44 of Set 14 | ouegoa
# Processing Record 45 of Set 14 | devarkonda
# Processing Record 46 of Set 14 | luyang
# Processing Record 47 of Set 14 | roald
# Processing Record 48 of Set 14 | tomari
# Processing Record 49 of Set 14 | eau claire
# Processing Record 50 of Set 14 | mayo
# Processing Record 1 of Set 15 | bagnols-sur-ceze
# Processing Record 2 of Set 15 | monte patria
# Processing Record 3 of Set 15 | victor harbor
# Processing Record 4 of Set 15 | minuri
# Processing Record 5 of Set 15 | dillon
# Processing Record 6 of Set 15 | opunake
# Processing Record 7 of Set 15 | tsumeb
# Processing Record 8 of Set 15 | obo
# Processing Record 9 of Set 15 | bay roberts
# Processing Record 10 of Set 15 | banda aceh
# Processing Record 11 of Set 15 | buzmeyin
# Processing Record 12 of Set 15 | lastoursville
# Processing Record 13 of Set 15 | praia da vitoria
# Processing Record 14 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 15 | north platte
# Processing Record 16 of Set 15 | taltal
# Processing Record 17 of Set 15 | huancabamba
# Processing Record 18 of Set 15 | papetoai
# Processing Record 19 of Set 15 | plettenberg bay
# Processing Record 20 of Set 15 | campbellsville
# Processing Record 21 of Set 15 | gladstone
# Processing Record 22 of Set 15 | warri
# Processing Record 23 of Set 15 | vao
# Processing Record 24 of Set 15 | ayni
# Processing Record 25 of Set 15 | limon
# Processing Record 26 of Set 15 | dandong
# Processing Record 27 of Set 15 | tolaga bay
# Processing Record 28 of Set 15 | bhimunipatnam
# Processing Record 29 of Set 15 | bhadrachalam
# Processing Record 30 of Set 15 | ouesso
# Processing Record 31 of Set 15 | etchoropo
# Processing Record 32 of Set 15 | uyovu
# Processing Record 33 of Set 15 | maceio
# Processing Record 34 of Set 15 | stulovo
# Processing Record 35 of Set 15 | jacmel
# Processing Record 36 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 37 of Set 15 | hasaki
# Processing Record 38 of Set 15 | aktau
# Processing Record 39 of Set 15 | venustiano carranza
# Processing Record 40 of Set 15 | dingalan
# Processing Record 41 of Set 15 | sindand
# City not found. Skipping...
# Processing Record 42 of Set 15 | fenoarivo
# Processing Record 43 of Set 15 | mbandaka
# Processing Record 44 of Set 15 | okha
# Processing Record 45 of Set 15 | carinhanha
# Processing Record 46 of Set 15 | dong hoi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =  pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hithadhoo  -0.6000   73.0833     80.49        75          20
# 1       Mataura -46.1927  168.8643     66.13        43          18
# 2       Qaanaaq  77.4840  -69.3632    -11.16        99         100
# 3  Punta Arenas -53.1500  -70.9167     59.11        36          75
# 4          Nome  64.5011 -165.4064      5.49        99          94
#
#    Wind Speed Country Current Description
# 0        8.48      MV          few clouds
# 1        7.36      NZ          few clouds
# 2        2.01      GL     overcast clouds
# 3       10.36      CL       broken clouds
# 4        4.52      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]
# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hithadhoo      MV  -0.6000   73.0833     80.49        75          20
# 1       Mataura      NZ -46.1927  168.8643     66.13        43          18
# 2       Qaanaaq      GL  77.4840  -69.3632    -11.16        99         100
# 3  Punta Arenas      CL -53.1500  -70.9167     59.11        36          75
# 4          Nome      US  64.5011 -165.4064      5.49        99          94
#
#    Wind Speed Current Description
# 0        8.48          few clouds
# 1        7.36          few clouds
# 2        2.01     overcast clouds
# 3       10.36       broken clouds
# 4        4.52     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = ("../Weather_Database/WeatherPy_Database.csv")

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label='City_ID')
