# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs =  np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qy/pfyb60j54dl63kwv0kswb82h0000gn/T/ipykernel_21791/2734285080.py in <module>
#       1 # Add the latitudes and longitudes to a list
# ----> 2 coordinates = list(lat_lngs)
#
# NameError: name 'lat_lngs' is not defined

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    for coordinate in coordinates:
        city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities lis
        if city not in cities:
            cities.append(city)


# Print the city count to confirm sufficient count
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qy/pfyb60j54dl63kwv0kswb82h0000gn/T/ipykernel_21791/4082755258.py in <module>
#       3
#       4 # Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
# ----> 5 for coordinate in coordinates:
#       6     # Use the citipy module to identify the nearest city to the current coordinate
#       7     for coordinate in coordinates:
#
# NameError: name 'coordinates' is not defined

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=12e82e638640666b8bb5af42e138c6f3

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity']
        clouds = city_weather['clouds']['all']
        wind = city_weather['wind']['speed']
        country = city_weather['sys']['country']      
        weather_description = city_weather['weather'][0]['description']
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),
                          'Lat': lat, 
                          'Lng': lng, 
                          'Max Temp': max_temp, 
                          'Humidity': humidity, 
                          'Cloudiness': clouds, 
                          'Wind Speed': wind, 
                          'Country': country, 
                          'Current Description': weather_description
                          })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | pitimbu
# Processing Record 4 of Set 1 | sao filipe
# Processing Record 5 of Set 1 | sobolevo
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | sanming
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | kapoeta
# Processing Record 15 of Set 1 | livramento
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | ca mau
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | trinidad
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | catuday
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | lavrentiya
# Processing Record 30 of Set 1 | saint-francois
# Processing Record 31 of Set 1 | retsag
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | flin flon
# Processing Record 34 of Set 1 | kualakapuas
# Processing Record 35 of Set 1 | cha grande
# Processing Record 36 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 1 | kyaikto
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | jiuquan
# Processing Record 40 of Set 1 | tecoanapa
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | la ronge
# Processing Record 43 of Set 1 | camacha
# Processing Record 44 of Set 1 | kalmunai
# Processing Record 45 of Set 1 | honiara
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | faanui
# Processing Record 48 of Set 1 | haines junction
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 1 of Set 2 | darhan
# Processing Record 2 of Set 2 | linxia
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | nabire
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | arcachon
# Processing Record 9 of Set 2 | santiago
# Processing Record 10 of Set 2 | juneau
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | banda aceh
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | mount isa
# Processing Record 15 of Set 2 | san luis rio colorado
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | golden
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | taltal
# Processing Record 22 of Set 2 | xudat
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | krasnyy chikoy
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | agadez
# Processing Record 27 of Set 2 | simpang
# Processing Record 28 of Set 2 | namatanai
# Processing Record 29 of Set 2 | maldonado
# Processing Record 30 of Set 2 | boat of garten
# Processing Record 31 of Set 2 | skagen
# Processing Record 32 of Set 2 | sorong
# Processing Record 33 of Set 2 | cap malheureux
# Processing Record 34 of Set 2 | qasigiannguit
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | topeka
# Processing Record 37 of Set 2 | gao
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | mnogovershinnyy
# Processing Record 41 of Set 2 | ternate
# Processing Record 42 of Set 2 | nenjiang
# Processing Record 43 of Set 2 | isangel
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | pundaguitan
# Processing Record 47 of Set 2 | ribeira brava
# Processing Record 48 of Set 2 | dahuk
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | faya
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | almaznyy
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | bintulu
# Processing Record 5 of Set 3 | meulaboh
# Processing Record 6 of Set 3 | coos bay
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | ahipara
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | progreso
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | prince rupert
# Processing Record 17 of Set 3 | puro
# Processing Record 18 of Set 3 | shahabad
# Processing Record 19 of Set 3 | dongsheng
# Processing Record 20 of Set 3 | half moon bay
# Processing Record 21 of Set 3 | mirnyy
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | nueva loja
# Processing Record 25 of Set 3 | nago
# Processing Record 26 of Set 3 | bassila
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | namibe
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | dingle
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | coahuayana
# Processing Record 36 of Set 3 | okhotsk
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | athabasca
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | laguna
# Processing Record 41 of Set 3 | denpasar
# Processing Record 42 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 3 | mananjary
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | hukuntsi
# Processing Record 47 of Set 3 | woodward
# Processing Record 48 of Set 3 | bisalpur
# Processing Record 49 of Set 3 | manbij
# Processing Record 50 of Set 3 | sinnamary
# Processing Record 1 of Set 4 | sistranda
# Processing Record 2 of Set 4 | kefamenanu
# Processing Record 3 of Set 4 | malegaon
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | sarangani
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | bell ville
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | playa vicente
# Processing Record 12 of Set 4 | imbituba
# Processing Record 13 of Set 4 | merida
# Processing Record 14 of Set 4 | atsiki
# City not found. Skipping...
# Processing Record 15 of Set 4 | benghazi
# Processing Record 16 of Set 4 | rio de janeiro
# Processing Record 17 of Set 4 | pedasi
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | ondjiva
# Processing Record 22 of Set 4 | gannan
# Processing Record 23 of Set 4 | whyalla
# Processing Record 24 of Set 4 | ankang
# Processing Record 25 of Set 4 | gunjur
# Processing Record 26 of Set 4 | guerrero negro
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | pacific grove
# Processing Record 30 of Set 4 | santa catalina
# Processing Record 31 of Set 4 | arlit
# Processing Record 32 of Set 4 | nanzhang
# Processing Record 33 of Set 4 | solnechnyy
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | vila franca do campo
# Processing Record 36 of Set 4 | tapejara
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | ambanja
# Processing Record 39 of Set 4 | vitim
# Processing Record 40 of Set 4 | alugan
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | tomatlan
# Processing Record 43 of Set 4 | madang
# Processing Record 44 of Set 4 | jamestown
# Processing Record 45 of Set 4 | esso
# Processing Record 46 of Set 4 | lensk
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | belousovka
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | lodja
# Processing Record 1 of Set 5 | paducah
# Processing Record 2 of Set 5 | bluff
# Processing Record 3 of Set 5 | yurginskoye
# Processing Record 4 of Set 5 | neyshabur
# Processing Record 5 of Set 5 | kapit
# Processing Record 6 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 5 | camocim
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | uyovu
# Processing Record 10 of Set 5 | taksimo
# Processing Record 11 of Set 5 | ouallam
# Processing Record 12 of Set 5 | salinopolis
# Processing Record 13 of Set 5 | baisha
# Processing Record 14 of Set 5 | kot putli
# City not found. Skipping...
# Processing Record 15 of Set 5 | marystown
# Processing Record 16 of Set 5 | pervouralsk
# Processing Record 17 of Set 5 | pingliang
# Processing Record 18 of Set 5 | zuidhorn
# Processing Record 19 of Set 5 | tecpan
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | svetlogorsk
# Processing Record 23 of Set 5 | adrar
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | iguape
# Processing Record 26 of Set 5 | auki
# Processing Record 27 of Set 5 | san cristobal
# Processing Record 28 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 5 | khandyga
# Processing Record 30 of Set 5 | matata
# Processing Record 31 of Set 5 | saint george
# Processing Record 32 of Set 5 | kurumkan
# Processing Record 33 of Set 5 | turochak
# Processing Record 34 of Set 5 | nome
# Processing Record 35 of Set 5 | kitui
# Processing Record 36 of Set 5 | nova olimpia
# Processing Record 37 of Set 5 | celestun
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | kongolo
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | manoel urbano
# Processing Record 43 of Set 5 | chokwe
# Processing Record 44 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 5 | bagotville
# Processing Record 46 of Set 5 | tual
# Processing Record 47 of Set 5 | port elizabeth
# Processing Record 48 of Set 5 | vallenar
# Processing Record 49 of Set 5 | fortuna
# Processing Record 50 of Set 5 | marsa matruh
# Processing Record 1 of Set 6 | yarmouth
# Processing Record 2 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 6 | tilichiki
# Processing Record 4 of Set 6 | constanza
# Processing Record 5 of Set 6 | kashi
# Processing Record 6 of Set 6 | agnibilekrou
# Processing Record 7 of Set 6 | kilindoni
# Processing Record 8 of Set 6 | kiunga
# Processing Record 9 of Set 6 | warrington
# Processing Record 10 of Set 6 | santa cruz de la palma
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | sorland
# Processing Record 13 of Set 6 | saint-georges
# Processing Record 14 of Set 6 | lauterbach
# Processing Record 15 of Set 6 | puerto ayacucho
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | khatanga
# Processing Record 18 of Set 6 | yarada
# Processing Record 19 of Set 6 | shahr-e babak
# Processing Record 20 of Set 6 | lasa
# Processing Record 21 of Set 6 | mount gambier
# Processing Record 22 of Set 6 | puerto escondido
# Processing Record 23 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | potchefstroom
# Processing Record 26 of Set 6 | poshekhonye
# Processing Record 27 of Set 6 | jacareacanga
# Processing Record 28 of Set 6 | mbanza-ngungu
# Processing Record 29 of Set 6 | ventspils
# Processing Record 30 of Set 6 | rivadavia
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | anahuac
# Processing Record 33 of Set 6 | ulaangom
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | taoudenni
# Processing Record 36 of Set 6 | sento se
# City not found. Skipping...
# Processing Record 37 of Set 6 | tautira
# Processing Record 38 of Set 6 | kremenchuk
# Processing Record 39 of Set 6 | takoradi
# Processing Record 40 of Set 6 | yanam
# Processing Record 41 of Set 6 | chuy
# Processing Record 42 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | saint-augustin
# Processing Record 46 of Set 6 | champerico
# Processing Record 47 of Set 6 | paamiut
# Processing Record 48 of Set 6 | mogeiro
# Processing Record 49 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 6 | porto novo
# Processing Record 1 of Set 7 | kibre mengist
# Processing Record 2 of Set 7 | mporokoso
# Processing Record 3 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 7 | somerset east
# Processing Record 5 of Set 7 | mabaruma
# Processing Record 6 of Set 7 | temir
# Processing Record 7 of Set 7 | zlitan
# Processing Record 8 of Set 7 | wenling
# Processing Record 9 of Set 7 | coquimbo
# Processing Record 10 of Set 7 | odoyev
# Processing Record 11 of Set 7 | belyy yar
# Processing Record 12 of Set 7 | el jicaro
# Processing Record 13 of Set 7 | kroya
# Processing Record 14 of Set 7 | conde
# Processing Record 15 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 7 | russell
# Processing Record 17 of Set 7 | kahului
# Processing Record 18 of Set 7 | gamba
# Processing Record 19 of Set 7 | bilma
# Processing Record 20 of Set 7 | quatre cocos
# Processing Record 21 of Set 7 | katherine
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | havelock
# Processing Record 24 of Set 7 | pouebo
# Processing Record 25 of Set 7 | tuatapere
# Processing Record 26 of Set 7 | vila velha
# Processing Record 27 of Set 7 | kihei
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | ola
# Processing Record 30 of Set 7 | rehoboth
# Processing Record 31 of Set 7 | mana
# Processing Record 32 of Set 7 | singkawang
# Processing Record 33 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 7 | kaman
# Processing Record 35 of Set 7 | grindavik
# Processing Record 36 of Set 7 | waipawa
# Processing Record 37 of Set 7 | digapahandi
# Processing Record 38 of Set 7 | belaya gora
# Processing Record 39 of Set 7 | vanavara
# Processing Record 40 of Set 7 | roma
# Processing Record 41 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 7 | walvis bay
# Processing Record 43 of Set 7 | sioux lookout
# Processing Record 44 of Set 7 | tateyama
# Processing Record 45 of Set 7 | codrington
# Processing Record 46 of Set 7 | maryborough
# Processing Record 47 of Set 7 | yamada
# Processing Record 48 of Set 7 | bay roberts
# Processing Record 49 of Set 7 | padang
# Processing Record 50 of Set 7 | gat
# Processing Record 1 of Set 8 | hamilton
# Processing Record 2 of Set 8 | port hardy
# Processing Record 3 of Set 8 | aksarka
# Processing Record 4 of Set 8 | villaviciosa
# Processing Record 5 of Set 8 | dong hoi
# Processing Record 6 of Set 8 | joensuu
# Processing Record 7 of Set 8 | oistins
# Processing Record 8 of Set 8 | cascais
# Processing Record 9 of Set 8 | hokitika
# Processing Record 10 of Set 8 | nikolskoye
# Processing Record 11 of Set 8 | jijiga
# Processing Record 12 of Set 8 | ponta do sol
# Processing Record 13 of Set 8 | tchollire
# Processing Record 14 of Set 8 | reconquista
# Processing Record 15 of Set 8 | akdagmadeni
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | port-gentil
# Processing Record 18 of Set 8 | chokurdakh
# Processing Record 19 of Set 8 | carutapera
# Processing Record 20 of Set 8 | straldza
# City not found. Skipping...
# Processing Record 21 of Set 8 | koumac
# Processing Record 22 of Set 8 | agadir
# Processing Record 23 of Set 8 | kirakira
# Processing Record 24 of Set 8 | kaseda
# Processing Record 25 of Set 8 | otane
# Processing Record 26 of Set 8 | port hedland
# Processing Record 27 of Set 8 | dunedin
# Processing Record 28 of Set 8 | baruun-urt
# Processing Record 29 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 8 | westport
# Processing Record 31 of Set 8 | kramat
# Processing Record 32 of Set 8 | olafsvik
# Processing Record 33 of Set 8 | sri aman
# Processing Record 34 of Set 8 | lokhvytsya
# Processing Record 35 of Set 8 | kutum
# Processing Record 36 of Set 8 | araouane
# Processing Record 37 of Set 8 | aripuana
# Processing Record 38 of Set 8 | phra phutthabat
# Processing Record 39 of Set 8 | vestmannaeyjar
# Processing Record 40 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | zaysan
# Processing Record 42 of Set 8 | constitucion
# Processing Record 43 of Set 8 | udala
# Processing Record 44 of Set 8 | barcelos
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | belmonte
# Processing Record 47 of Set 8 | morristown
# Processing Record 48 of Set 8 | henties bay
# Processing Record 49 of Set 8 | naliya
# Processing Record 50 of Set 8 | socorro
# Processing Record 1 of Set 9 | waddan
# Processing Record 2 of Set 9 | vegueta
# Processing Record 3 of Set 9 | ayan
# Processing Record 4 of Set 9 | te anau
# Processing Record 5 of Set 9 | kuah
# Processing Record 6 of Set 9 | esterhazy
# Processing Record 7 of Set 9 | rocha
# Processing Record 8 of Set 9 | cayenne
# Processing Record 9 of Set 9 | muros
# Processing Record 10 of Set 9 | upata
# Processing Record 11 of Set 9 | ashland
# Processing Record 12 of Set 9 | murom
# Processing Record 13 of Set 9 | katsuura
# Processing Record 14 of Set 9 | alofi
# Processing Record 15 of Set 9 | port blair
# Processing Record 16 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 9 | gisborne
# Processing Record 18 of Set 9 | virginia beach
# Processing Record 19 of Set 9 | kenai
# Processing Record 20 of Set 9 | port augusta
# Processing Record 21 of Set 9 | uchiza
# Processing Record 22 of Set 9 | dudinka
# Processing Record 23 of Set 9 | rantepao
# Processing Record 24 of Set 9 | jawhar
# Processing Record 25 of Set 9 | turinsk
# Processing Record 26 of Set 9 | pizarro
# Processing Record 27 of Set 9 | touros
# Processing Record 28 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 9 | portland
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | korla
# Processing Record 32 of Set 9 | kathu
# Processing Record 33 of Set 9 | santa rosa
# Processing Record 34 of Set 9 | shaoguan
# Processing Record 35 of Set 9 | los llanos de aridane
# Processing Record 36 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 9 | sao borja
# Processing Record 38 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 9 | chahuites
# Processing Record 40 of Set 9 | filingue
# Processing Record 41 of Set 9 | boqueron
# Processing Record 42 of Set 9 | yerbogachen
# Processing Record 43 of Set 9 | hit
# Processing Record 44 of Set 9 | zaragoza
# Processing Record 45 of Set 9 | imeni poliny osipenko
# Processing Record 46 of Set 9 | iquique
# Processing Record 47 of Set 9 | jelgava
# Processing Record 48 of Set 9 | port macquarie
# Processing Record 49 of Set 9 | wajima
# Processing Record 50 of Set 9 | ornskoldsvik
# Processing Record 1 of Set 10 | nanortalik
# Processing Record 2 of Set 10 | kirksville
# Processing Record 3 of Set 10 | mogochin
# City not found. Skipping...
# Processing Record 4 of Set 10 | nanuque
# Processing Record 5 of Set 10 | columbus
# Processing Record 6 of Set 10 | askos
# Processing Record 7 of Set 10 | udachnyy
# Processing Record 8 of Set 10 | drumheller
# Processing Record 9 of Set 10 | ahuimanu
# Processing Record 10 of Set 10 | puerto del rosario
# Processing Record 11 of Set 10 | porrentruy
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | fort frances
# Processing Record 14 of Set 10 | daru
# Processing Record 15 of Set 10 | richards bay
# Processing Record 16 of Set 10 | zyryanovskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | berlevag
# Processing Record 18 of Set 10 | touho
# Processing Record 19 of Set 10 | kayerkan
# Processing Record 20 of Set 10 | mocuba
# Processing Record 21 of Set 10 | ixtapa
# Processing Record 22 of Set 10 | emerald
# Processing Record 23 of Set 10 | evensk
# Processing Record 24 of Set 10 | gonbad-e qabus
# Processing Record 25 of Set 10 | puerto colombia
# Processing Record 26 of Set 10 | pergamino
# Processing Record 27 of Set 10 | odweyne
# Processing Record 28 of Set 10 | naousa
# Processing Record 29 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 10 | canon city
# Processing Record 31 of Set 10 | meilu
# City not found. Skipping...
# Processing Record 32 of Set 10 | sainte-marie
# Processing Record 33 of Set 10 | craig
# Processing Record 34 of Set 10 | rupert
# Processing Record 35 of Set 10 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 36 of Set 10 | leninskoye
# Processing Record 37 of Set 10 | maniitsoq
# Processing Record 38 of Set 10 | shirakawa
# Processing Record 39 of Set 10 | skjervoy
# Processing Record 40 of Set 10 | bosaso
# Processing Record 41 of Set 10 | mikkeli
# Processing Record 42 of Set 10 | lompoc
# Processing Record 43 of Set 10 | chamlykskaya
# Processing Record 44 of Set 10 | bissau
# Processing Record 45 of Set 10 | pangai
# Processing Record 46 of Set 10 | arman
# Processing Record 47 of Set 10 | konza
# Processing Record 48 of Set 10 | tartagal
# Processing Record 49 of Set 10 | inirida
# Processing Record 50 of Set 10 | vao
# Processing Record 1 of Set 11 | karasburg
# Processing Record 2 of Set 11 | port lincoln
# Processing Record 3 of Set 11 | steamboat springs
# Processing Record 4 of Set 11 | pevek
# Processing Record 5 of Set 11 | palmer
# Processing Record 6 of Set 11 | jumla
# Processing Record 7 of Set 11 | broome
# Processing Record 8 of Set 11 | general pico
# Processing Record 9 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 11 | freeport
# Processing Record 11 of Set 11 | severnoye
# Processing Record 12 of Set 11 | crixas
# Processing Record 13 of Set 11 | linguere
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | tammisaari
# Processing Record 16 of Set 11 | rio grande
# Processing Record 17 of Set 11 | makurdi
# Processing Record 18 of Set 11 | nemuro
# Processing Record 19 of Set 11 | la seyne-sur-mer
# Processing Record 20 of Set 11 | hervey bay
# Processing Record 21 of Set 11 | mangrol
# Processing Record 22 of Set 11 | malakal
# Processing Record 23 of Set 11 | totskoye
# Processing Record 24 of Set 11 | rincon
# Processing Record 25 of Set 11 | flinders
# Processing Record 26 of Set 11 | nelson bay
# Processing Record 27 of Set 11 | debre tabor
# Processing Record 28 of Set 11 | taywarah
# Processing Record 29 of Set 11 | mitu
# Processing Record 30 of Set 11 | naze
# Processing Record 31 of Set 11 | kochki
# Processing Record 32 of Set 11 | mayo
# Processing Record 33 of Set 11 | port-cartier
# Processing Record 34 of Set 11 | mae sai
# Processing Record 35 of Set 11 | gigmoto
# Processing Record 36 of Set 11 | myanaung
# Processing Record 37 of Set 11 | floro
# Processing Record 38 of Set 11 | asamankese
# Processing Record 39 of Set 11 | natal
# Processing Record 40 of Set 11 | curuca
# Processing Record 41 of Set 11 | kochubey
# Processing Record 42 of Set 11 | cairns
# Processing Record 43 of Set 11 | emet
# Processing Record 44 of Set 11 | bubaque
# Processing Record 45 of Set 11 | kurilsk
# Processing Record 46 of Set 11 | bocaiuva
# Processing Record 47 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 11 | tefe
# Processing Record 49 of Set 11 | kismayo
# Processing Record 50 of Set 11 | keti bandar
# Processing Record 1 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 12 | aswan
# Processing Record 3 of Set 12 | pagman
# City not found. Skipping...
# Processing Record 4 of Set 12 | altamira
# Processing Record 5 of Set 12 | marrakesh
# Processing Record 6 of Set 12 | mandera
# Processing Record 7 of Set 12 | marsaxlokk
# Processing Record 8 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 12 | vryburg
# Processing Record 10 of Set 12 | nador
# Processing Record 11 of Set 12 | santa lucia
# Processing Record 12 of Set 12 | bandarbeyla
# Processing Record 13 of Set 12 | olga
# Processing Record 14 of Set 12 | paita
# Processing Record 15 of Set 12 | shubarkuduk
# Processing Record 16 of Set 12 | bourg-en-bresse
# Processing Record 17 of Set 12 | north bend
# Processing Record 18 of Set 12 | winnemucca
# Processing Record 19 of Set 12 | antalaha
# Processing Record 20 of Set 12 | qandala
# Processing Record 21 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 12 | tsumeb
# Processing Record 23 of Set 12 | asyut
# Processing Record 24 of Set 12 | eureka
# Processing Record 25 of Set 12 | puliyankudi
# Processing Record 26 of Set 12 | margate
# Processing Record 27 of Set 12 | mehriz
# Processing Record 28 of Set 12 | shimoda
# Processing Record 29 of Set 12 | thomasville
# Processing Record 30 of Set 12 | sabang
# Processing Record 31 of Set 12 | la ligua
# Processing Record 32 of Set 12 | moose factory
# Processing Record 33 of Set 12 | manaus
# Processing Record 34 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 35 of Set 12 | rafai
# Processing Record 36 of Set 12 | adet
# Processing Record 37 of Set 12 | pozo colorado
# Processing Record 38 of Set 12 | manyoni
# Processing Record 39 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 12 | burgeo
# Processing Record 42 of Set 12 | shelburne
# Processing Record 43 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 12 | abeche
# Processing Record 45 of Set 12 | kanadey
# Processing Record 46 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 12 | bridlington
# Processing Record 48 of Set 12 | whitehorse
# Processing Record 49 of Set 12 | wuhu
# Processing Record 50 of Set 12 | sagaing
# Processing Record 1 of Set 13 | forbes
# Processing Record 2 of Set 13 | swan hill
# Processing Record 3 of Set 13 | atambua
# Processing Record 4 of Set 13 | manzanillo
# Processing Record 5 of Set 13 | cockburn town
# Processing Record 6 of Set 13 | jacmel
# Processing Record 7 of Set 13 | verkhnevilyuysk
# Processing Record 8 of Set 13 | lieksa
# Processing Record 9 of Set 13 | carauari
# Processing Record 10 of Set 13 | ladario
# Processing Record 11 of Set 13 | albanel
# Processing Record 12 of Set 13 | seoul
# Processing Record 13 of Set 13 | pangoa
# Processing Record 14 of Set 13 | nurota
# Processing Record 15 of Set 13 | komsomolskiy
# Processing Record 16 of Set 13 | glenwood springs
# Processing Record 17 of Set 13 | kongoussi
# Processing Record 18 of Set 13 | olinda
# Processing Record 19 of Set 13 | havre-saint-pierre
# Processing Record 20 of Set 13 | sumbe
# Processing Record 21 of Set 13 | luganville
# Processing Record 22 of Set 13 | sisimiut
# Processing Record 23 of Set 13 | vlore
# Processing Record 24 of Set 13 | husavik
# Processing Record 25 of Set 13 | makokou
# Processing Record 26 of Set 13 | batagay-alyta
# Processing Record 27 of Set 13 | iqaluit
# Processing Record 28 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 13 | comodoro rivadavia
# Processing Record 30 of Set 13 | san ramon
# Processing Record 31 of Set 13 | ngunguru
# Processing Record 32 of Set 13 | mulchen
# Processing Record 33 of Set 13 | balabac
# Processing Record 34 of Set 13 | dapaong
# Processing Record 35 of Set 13 | sokoni
# Processing Record 36 of Set 13 | seydi
# Processing Record 37 of Set 13 | seddon
# Processing Record 38 of Set 13 | nevelsk
# Processing Record 39 of Set 13 | klyuchi
# Processing Record 40 of Set 13 | oum hadjer
# Processing Record 41 of Set 13 | yumen
# Processing Record 42 of Set 13 | otradnyy
# Processing Record 43 of Set 13 | polovinnoye
# Processing Record 44 of Set 13 | seryshevo
# Processing Record 45 of Set 13 | samarai
# Processing Record 46 of Set 13 | dubti
# Processing Record 47 of Set 13 | nhulunbuy
# Processing Record 48 of Set 13 | alabaster
# Processing Record 49 of Set 13 | goure
# Processing Record 50 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 14 | lingao
# Processing Record 2 of Set 14 | tome
# Processing Record 3 of Set 14 | nishihara
# Processing Record 4 of Set 14 | miguel alves
# Processing Record 5 of Set 14 | ampanihy
# Processing Record 6 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 14 | ossora
# Processing Record 8 of Set 14 | mercedes
# Processing Record 9 of Set 14 | nova londrina
# Processing Record 10 of Set 14 | matamoros
# Processing Record 11 of Set 14 | suluq
# Processing Record 12 of Set 14 | finnsnes
# Processing Record 13 of Set 14 | madimba
# Processing Record 14 of Set 14 | abalak
# Processing Record 15 of Set 14 | kohima
# Processing Record 16 of Set 14 | bayangol
# Processing Record 17 of Set 14 | lewistown
# Processing Record 18 of Set 14 | watertown
# Processing Record 19 of Set 14 | beringovskiy
# Processing Record 20 of Set 14 | hasaki
# Processing Record 21 of Set 14 | elliot lake
# Processing Record 22 of Set 14 | gardan diwal
# City not found. Skipping...
# Processing Record 23 of Set 14 | bondoukou
# Processing Record 24 of Set 14 | hambantota
# Processing Record 25 of Set 14 | tezu
# Processing Record 26 of Set 14 | inhambane
# Processing Record 27 of Set 14 | buala
# Processing Record 28 of Set 14 | ambilobe
# Processing Record 29 of Set 14 | peniche
# Processing Record 30 of Set 14 | lalibela
# Processing Record 31 of Set 14 | royken
# Processing Record 32 of Set 14 | dyurtyuli
# Processing Record 33 of Set 14 | nouadhibou
# Processing Record 34 of Set 14 | barcarena
# Processing Record 35 of Set 14 | huilong
# Processing Record 36 of Set 14 | axtla
# City not found. Skipping...
# Processing Record 37 of Set 14 | monmouth
# Processing Record 38 of Set 14 | mahajanga
# Processing Record 39 of Set 14 | safford
# Processing Record 40 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 41 of Set 14 | khor
# Processing Record 42 of Set 14 | siavonga
# Processing Record 43 of Set 14 | goderich
# Processing Record 44 of Set 14 | vagur
# Processing Record 45 of Set 14 | avera
# Processing Record 46 of Set 14 | capao da canoa
# Processing Record 47 of Set 14 | heze
# Processing Record 48 of Set 14 | pisco
# Processing Record 49 of Set 14 | xining
# Processing Record 50 of Set 14 | mbandaka
# Processing Record 1 of Set 15 | severnyy-kospashskiy
# Processing Record 2 of Set 15 | san luis
# Processing Record 3 of Set 15 | atoyac
# Processing Record 4 of Set 15 | yar-sale
# Processing Record 5 of Set 15 | mbuji-mayi
# Processing Record 6 of Set 15 | rawson
# Processing Record 7 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 15 | hella
# Processing Record 9 of Set 15 | helena
# Processing Record 10 of Set 15 | pedra azul
# Processing Record 11 of Set 15 | jinchang
# Processing Record 12 of Set 15 | hirara
# Processing Record 13 of Set 15 | las palmas
# Processing Record 14 of Set 15 | santa catarina de tepehuanes
# Processing Record 15 of Set 15 | dedougou
# Processing Record 16 of Set 15 | eydhafushi
# Processing Record 17 of Set 15 | george
# Processing Record 18 of Set 15 | churapcha
# Processing Record 19 of Set 15 | grafenhainichen
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | erzin
# Processing Record 22 of Set 15 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 23 of Set 15 | charters towers
# Processing Record 24 of Set 15 | kaniama
# Processing Record 25 of Set 15 | egvekinot
# Processing Record 26 of Set 15 | gimbi
# Processing Record 27 of Set 15 | sao felix do xingu
# Processing Record 28 of Set 15 | anadyr
# Processing Record 29 of Set 15 | kloulklubed
# Processing Record 30 of Set 15 | high level
# Processing Record 31 of Set 15 | bandundu
# Processing Record 32 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 33 of Set 15 | kangaatsiaq
# Processing Record 34 of Set 15 | alamos
# Processing Record 35 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 15 | palana
# Processing Record 37 of Set 15 | mayya
# Processing Record 38 of Set 15 | manaure
# Processing Record 39 of Set 15 | terre haute
# Processing Record 40 of Set 15 | plettenberg bay
# Processing Record 41 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 43 of Set 15 | itarema
# Processing Record 44 of Set 15 | dalen
# Processing Record 45 of Set 15 | meadow lake
# Processing Record 46 of Set 15 | chumikan
# Processing Record 47 of Set 15 | maua
# Processing Record 48 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 49 of Set 15 | gombong
# Processing Record 50 of Set 15 | resistencia
# Processing Record 1 of Set 16 | qafsah
# City not found. Skipping...
# Processing Record 2 of Set 16 | jimenez
# Processing Record 3 of Set 16 | kisangani
# Processing Record 4 of Set 16 | dharchula
# Processing Record 5 of Set 16 | zhigansk
# Processing Record 6 of Set 16 | el chichicaste
# Processing Record 7 of Set 16 | senno
# Processing Record 8 of Set 16 | ericeira
# Processing Record 9 of Set 16 | myre
# Processing Record 10 of Set 16 | zabaykalsk
# Processing Record 11 of Set 16 | podgornoye
# Processing Record 12 of Set 16 | trairi
# Processing Record 13 of Set 16 | paraguacu paulista
# Processing Record 14 of Set 16 | mau aima
# City not found. Skipping...
# Processing Record 15 of Set 16 | thinadhoo
# Processing Record 16 of Set 16 | kieta
# Processing Record 17 of Set 16 | krasyliv
# Processing Record 18 of Set 16 | skibbereen
# Processing Record 19 of Set 16 | acopiara
# Processing Record 20 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 16 | angleton
# Processing Record 22 of Set 16 | wellington
# Processing Record 23 of Set 16 | yigou
# Processing Record 24 of Set 16 | beloha
# Processing Record 25 of Set 16 | porto velho
# Processing Record 26 of Set 16 | broken hill
# Processing Record 27 of Set 16 | noumea
# Processing Record 28 of Set 16 | rovenki
# Processing Record 29 of Set 16 | road town
# Processing Record 30 of Set 16 | manta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 715

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =  pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bengkulu  -3.8004  102.2655     73.45        91          89
# 1  Norman Wells  65.2820 -126.8329     -9.36        77         100
# 2       Pitimbu  -7.4706  -34.8086     79.39        76          38
# 3    Sao Filipe  14.8961  -24.4956     75.51        64         100
# 4      Sobolevo  54.4299   31.8996     10.90        88         100
#
#    Wind Speed Country Current Description
# 0        4.50      ID          light rain
# 1        0.00      CA     overcast clouds
# 2       11.50      BR    scattered clouds
# 3       10.49      CV     overcast clouds
# 4       13.89      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]
# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bengkulu      ID  -3.8004  102.2655     73.45        91          89
# 1  Norman Wells      CA  65.2820 -126.8329     -9.36        77         100
# 2       Pitimbu      BR  -7.4706  -34.8086     79.39        76          38
# 3    Sao Filipe      CV  14.8961  -24.4956     75.51        64         100
# 4      Sobolevo      RU  54.4299   31.8996     10.90        88         100
#
#    Wind Speed Current Description
# 0        4.50          light rain
# 1        0.00     overcast clouds
# 2       11.50    scattered clouds
# 3       10.49     overcast clouds
# 4       13.89     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = ("../Weather_Database/WeatherPy_Database.csv")

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label='City_ID')
